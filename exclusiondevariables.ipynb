# %%
# -*- coding: utf-8 -*-
# Entrenamiento supervisado con PyCaret (XGBoost) + chequeo anti-leakage (PyCaret 3.x)

import os
import warnings
import pandas as pd
from pycaret.classification import (
    setup, compare_models, create_model, tune_model,
    plot_model, predict_model, finalize_model, save_model, pull
)

warnings.filterwarnings("ignore")

# ---------------------------------------------------------
# 1) Configuración
# ---------------------------------------------------------
RUTA_CSV = r"C:\Users\FABIO\Downloads\dataset_hoteles_tunja_50000_segmentado.csv"
TARGET = "segmento"
SEED = 42
FOLDS = 5
RESULTS_DIR = os.path.abspath("./resultados_segmento")
os.makedirs(RESULTS_DIR, exist_ok=True)

# ---------------------------------------------------------
# 2) Cargar datos y detectar columnas a ignorar
# ---------------------------------------------------------
df = pd.read_csv(RUTA_CSV, encoding="utf-8-sig")
if TARGET not in df.columns:
    raise ValueError(f"No se encontró la columna objetivo '{TARGET}'. ¿Usas el CSV segmentado?")

DERIVADAS_CANDIDATAS = {
    'score_premium','amenities_count','cal_norm','amenities_norm',
    'reputacion_score','reputacion_norm','limpieza_score','limpieza_norm',
    'nivel_servicios','indice_valor'
}
derivadas_presentes = [c for c in df.columns if c in DERIVADAS_CANDIDATAS]

texto_largo = []
for c in df.columns:
    if c != TARGET and df[c].dtype == object:
        try:
            if df[c].str.len().fillna(0).mean() > 60:
                texto_largo.append(c)
        except Exception:
            pass

print("Columnas derivadas (posible leakage):", derivadas_presentes)
print("Columnas de texto largo ignoradas:", texto_largo)

# ---------------------------------------------------------
# 3) Función de experimento
# ---------------------------------------------------------
def correr_experimento(nombre, ignore_features=None):
    print(f"\n=== Experimento: {nombre} ===")
    s = setup(
        data=df,
        target=TARGET,
        session_id=SEED,
        fold=FOLDS,
        verbose=False,           # <- quitar 'silent'
        ignore_features=ignore_features
    )

    # Comparación para documentación
    _ = compare_models(sort='F1')
    tabla_compare = pull()
    tabla_compare.to_csv(os.path.join(RESULTS_DIR, f"compare_models_{nombre}.csv"),
                         index=False, encoding="utf-8-sig")

    # XGBoost: crear, afinar y evaluar
    xgb = create_model('xgboost')
    pull().to_csv(os.path.join(RESULTS_DIR, f"xgb_cv_{nombre}.csv"),
                  index=False, encoding="utf-8-sig")

    xgb_tuned = tune_model(xgb, optimize='F1')
    pull().to_csv(os.path.join(RESULTS_DIR, f"xgb_tuned_cv_{nombre}.csv"),
                  index=False, encoding="utf-8-sig")

    # Plots (se guardan en ./Plots)
    plot_model(xgb_tuned, plot='confusion_matrix', save=True)
    plot_model(xgb_tuned, plot='feature', save=True)
    try:
        plot_model(xgb_tuned, plot='class_report', save=True)
    except Exception as e:
        print("Aviso: 'class_report' no disponible en esta versión ->", e)

    # Interpretabilidad (opcional, requiere shap)
    try:
        from pycaret.classification import interpret_model
        interpret_model(xgb_tuned, plot='summary', save=True)
    except Exception as e:
        print("Aviso: SHAP no disponible / no se pudo generar interpretabilidad ->", e)

    # Predicción holdout y métricas
    pred_holdout = predict_model(xgb_tuned)
    pred_holdout.to_csv(os.path.join(RESULTS_DIR, f"holdout_preds_{nombre}.csv"),
                        index=False, encoding="utf-8-sig")
    pull().to_csv(os.path.join(RESULTS_DIR, f"holdout_metrics_{nombre}.csv"),
                  index=False, encoding="utf-8-sig")

    # Modelo final
    final_xgb = finalize_model(xgb_tuned)
    save_model(final_xgb, os.path.join(RESULTS_DIR, f"modelo_xgb_{nombre}"))

# ---------------------------------------------------------
# 4) Ejecutar escenarios
# ---------------------------------------------------------
# A) Con todo (menos texto enorme)
IGNORE_A = texto_largo.copy()
correr_experimento("A_todo", ignore_features=IGNORE_A)

# B) Anti-leakage (quita derivadas + texto enorme)
IGNORE_B = list(set(texto_largo + derivadas_presentes))
correr_experimento("B_antileak", ignore_features=IGNORE_B)

print("\nListo. Revisa la carpeta:", RESULTS_DIR, "y la subcarpeta ./Plots")
# Out:
# Columnas derivadas (posible leakage): ['reputacion_score', 'limpieza_score', 'cal_norm', 'amenities_norm', 'reputacion_norm', 'limpieza_norm', 'amenities_count', 'nivel_servicios', 'indice_valor', 'score_premium']
# Columnas de texto largo ignoradas: []
#
# === Experimento: A_todo ===
# <style type="text/css">
# #T_8003f th {
#   text-align: left;
# }
# #T_8003f_row0_col0, #T_8003f_row1_col0, #T_8003f_row2_col0, #T_8003f_row2_col2, #T_8003f_row3_col0, #T_8003f_row3_col2, #T_8003f_row4_col0, #T_8003f_row5_col0, #T_8003f_row6_col0, #T_8003f_row7_col0, #T_8003f_row7_col1, #T_8003f_row7_col3, #T_8003f_row7_col4, #T_8003f_row7_col5, #T_8003f_row7_col6, #T_8003f_row7_col7, #T_8003f_row8_col0, #T_8003f_row8_col1, #T_8003f_row8_col2, #T_8003f_row8_col3, #T_8003f_row8_col4, #T_8003f_row8_col5, #T_8003f_row8_col6, #T_8003f_row8_col7, #T_8003f_row9_col0, #T_8003f_row9_col1, #T_8003f_row9_col2, #T_8003f_row9_col3, #T_8003f_row9_col4, #T_8003f_row9_col5, #T_8003f_row9_col6, #T_8003f_row9_col7, #T_8003f_row10_col0, #T_8003f_row10_col1, #T_8003f_row10_col2, #T_8003f_row10_col3, #T_8003f_row10_col4, #T_8003f_row10_col5, #T_8003f_row10_col6, #T_8003f_row10_col7, #T_8003f_row11_col0, #T_8003f_row11_col1, #T_8003f_row11_col2, #T_8003f_row11_col3, #T_8003f_row11_col4, #T_8003f_row11_col5, #T_8003f_row11_col6, #T_8003f_row11_col7, #T_8003f_row12_col0, #T_8003f_row12_col1, #T_8003f_row12_col2, #T_8003f_row12_col3, #T_8003f_row12_col4, #T_8003f_row12_col5, #T_8003f_row12_col6, #T_8003f_row12_col7, #T_8003f_row13_col0, #T_8003f_row13_col1, #T_8003f_row13_col2, #T_8003f_row13_col3, #T_8003f_row13_col4, #T_8003f_row13_col5, #T_8003f_row13_col6, #T_8003f_row13_col7, #T_8003f_row14_col0, #T_8003f_row14_col1, #T_8003f_row14_col2, #T_8003f_row14_col3, #T_8003f_row14_col4, #T_8003f_row14_col5, #T_8003f_row14_col6, #T_8003f_row14_col7, #T_8003f_row15_col0, #T_8003f_row15_col1, #T_8003f_row15_col2, #T_8003f_row15_col3, #T_8003f_row15_col4, #T_8003f_row15_col5, #T_8003f_row15_col6, #T_8003f_row15_col7 {
#   text-align: left;
# }
# #T_8003f_row0_col1, #T_8003f_row0_col2, #T_8003f_row0_col3, #T_8003f_row0_col4, #T_8003f_row0_col5, #T_8003f_row0_col6, #T_8003f_row0_col7, #T_8003f_row1_col1, #T_8003f_row1_col2, #T_8003f_row1_col3, #T_8003f_row1_col4, #T_8003f_row1_col5, #T_8003f_row1_col6, #T_8003f_row1_col7, #T_8003f_row2_col1, #T_8003f_row2_col3, #T_8003f_row2_col4, #T_8003f_row2_col5, #T_8003f_row2_col6, #T_8003f_row2_col7, #T_8003f_row3_col1, #T_8003f_row3_col3, #T_8003f_row3_col4, #T_8003f_row3_col5, #T_8003f_row3_col6, #T_8003f_row3_col7, #T_8003f_row4_col1, #T_8003f_row4_col2, #T_8003f_row4_col3, #T_8003f_row4_col4, #T_8003f_row4_col5, #T_8003f_row4_col6, #T_8003f_row4_col7, #T_8003f_row5_col1, #T_8003f_row5_col2, #T_8003f_row5_col3, #T_8003f_row5_col4, #T_8003f_row5_col5, #T_8003f_row5_col6, #T_8003f_row5_col7, #T_8003f_row6_col1, #T_8003f_row6_col2, #T_8003f_row6_col3, #T_8003f_row6_col4, #T_8003f_row6_col5, #T_8003f_row6_col6, #T_8003f_row6_col7, #T_8003f_row7_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_8003f_row0_col8, #T_8003f_row1_col8, #T_8003f_row2_col8, #T_8003f_row3_col8, #T_8003f_row4_col8, #T_8003f_row5_col8, #T_8003f_row6_col8, #T_8003f_row7_col8, #T_8003f_row8_col8, #T_8003f_row9_col8, #T_8003f_row10_col8, #T_8003f_row11_col8, #T_8003f_row12_col8, #T_8003f_row13_col8, #T_8003f_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_8003f_row15_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_8003f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8003f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8003f_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_8003f_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_8003f_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_8003f_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_8003f_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_8003f_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_8003f_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_8003f_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8003f_level0_row0" class="row_heading level0 row0" >dt</th>
#       <td id="T_8003f_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_8003f_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_8003f_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_8003f_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_8003f_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_8003f_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_8003f_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_8003f_row0_col7" class="data row0 col7" >1.0000</td>
#       <td id="T_8003f_row0_col8" class="data row0 col8" >1.5440</td>
#     </tr>
#     <tr>
#       <th id="T_8003f_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_8003f_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_8003f_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_8003f_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_8003f_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_8003f_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_8003f_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_8003f_row1_col6" class="data row1 col6" >1.0000</td>
#       <td id="T_8003f_row1_col7" class="data row1 col7" >1.0000</td>
#       <td id="T_8003f_row1_col8" class="data row1 col8" >0.6740</td>
#     </tr>
#     <tr>
#       <th id="T_8003f_level0_row2" class="row_heading level0 row2" >ada</th>
#       <td id="T_8003f_row2_col0" class="data row2 col0" >Ada Boost Classifier</td>
#       <td id="T_8003f_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_8003f_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_8003f_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_8003f_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_8003f_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_8003f_row2_col6" class="data row2 col6" >1.0000</td>
#       <td id="T_8003f_row2_col7" class="data row2 col7" >1.0000</td>
#       <td id="T_8003f_row2_col8" class="data row2 col8" >0.9720</td>
#     </tr>
#     <tr>
#       <th id="T_8003f_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_8003f_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_8003f_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_8003f_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_8003f_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_8003f_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_8003f_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_8003f_row3_col6" class="data row3 col6" >1.0000</td>
#       <td id="T_8003f_row3_col7" class="data row3 col7" >1.0000</td>
#       <td id="T
#T_ffd65_row3_col4, #T_ffd65_row3_col5, #T_ffd65_row3_col6, #T_ffd65_row3_col7, #T_ffd65_row4_col0, #T_ffd65_row4_col1, #T_ffd65_row4_col2, #T_ffd65_row4_col3, #T_ffd65_row4_col4, #T_ffd65_row4_col5, #T_ffd65_row4_col6, #T_ffd65_row4_col7, #T_ffd65_row5_col0, #T_ffd65_row5_col1, #T_ffd65_row5_col2, #T_ffd65_row5_col3, #T_ffd65_row5_col4, #T_ffd65_row5_col5, #T_ffd65_row5_col6, #T_ffd65_row5_col7, #T_ffd65_row6_col0, #T_ffd65_row6_col1, #T_ffd65_row6_col2, #T_ffd65_row6_col3, #T_ffd65_row6_col4, #T_ffd65_row6_col5, #T_ffd65_row6_col6, #T_ffd65_row6_col7, #T_ffd65_row7_col0, #T_ffd65_row7_col1, #T_ffd65_row7_col2, #T_ffd65_row7_col3, #T_ffd65_row7_col4, #T_ffd65_row7_col5, #T_ffd65_row7_col6, #T_ffd65_row7_col7, #T_ffd65_row8_col0, #T_ffd65_row8_col1, #T_ffd65_row8_col2, #T_ffd65_row8_col3, #T_ffd65_row8_col4, #T_ffd65_row8_col5, #T_ffd65_row8_col6, #T_ffd65_row8_col7, #T_ffd65_row9_col0, #T_ffd65_row9_col1, #T_ffd65_row9_col2, #T_ffd65_row9_col3, #T_ffd65_row9_col4, #T_ffd65_row9_col5, #T_ffd65_row9_col6, #T_ffd65_row9_col7, #T_ffd65_row10_col0, #T_ffd65_row10_col1, #T_ffd65_row10_col2, #T_ffd65_row10_col3, #T_ffd65_row10_col4, #T_ffd65_row10_col5, #T_ffd65_row10_col6, #T_ffd65_row10_col7, #T_ffd65_row11_col0, #T_ffd65_row11_col1, #T_ffd65_row11_col2, #T_ffd65_row11_col3, #T_ffd65_row11_col4, #T_ffd65_row11_col5, #T_ffd65_row11_col6, #T_ffd65_row11_col7, #T_ffd65_row12_col0, #T_ffd65_row12_col1, #T_ffd65_row12_col2, #T_ffd65_row12_col3, #T_ffd65_row12_col4, #T_ffd65_row12_col5, #T_ffd65_row12_col6, #T_ffd65_row12_col7, #T_ffd65_row13_col0, #T_ffd65_row13_col1, #T_ffd65_row13_col2, #T_ffd65_row13_col3, #T_ffd65_row13_col4, #T_ffd65_row13_col5, #T_ffd65_row13_col6, #T_ffd65_row13_col7, #T_ffd65_row14_col0, #T_ffd65_row14_col1, #T_ffd65_row14_col2, #T_ffd65_row14_col3, #T_ffd65_row14_col4, #T_ffd65_row14_col5, #T_ffd65_row14_col6, #T_ffd65_row14_col7, #T_ffd65_row15_col0, #T_ffd65_row15_col1, #T_ffd65_row15_col2, #T_ffd65_row15_col3, #T_ffd65_row15_col4, #T_ffd65_row15_col5, #T_ffd65_row15_col6, #T_ffd65_row15_col7 {
#   text-align: left;
# }
# #T_ffd65_row0_col1, #T_ffd65_row0_col3, #T_ffd65_row0_col4, #T_ffd65_row0_col5, #T_ffd65_row0_col6, #T_ffd65_row0_col7, #T_ffd65_row1_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_
row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_ffd65_row4_col3" class="data row4 col3" >0.9683</td>
#       <td id="T_ffd65_row4_col4" class="data row4 col4" >0.9683</td>
#       <td id="T_ffd65_row4_col5" class="data row4 col5" >0.9682</td>
#       <td id="T_ffd65_row4_col6" class="data row4 col6" >0.9524</td>
#       <td id="T_ffd65_row4_col7" class="data row4 col7" >0.9525</td>
#       <td id="T_ffd65_row4_col8" class="data row4 col8" >4.1780</td>
#     </tr>
#     <tr>
#       <th id="T_ffd65_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_ffd65_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_ffd65_row5_col1" class="data row5 col1" >0.9673</td>
#       <td id="T_ffd65_row5_col2"
# <style type="text/css">
# #T_6c545_row5_col0, #T_6c545_row5_col1, #T_6c545_row5_col2, #T_6c545_row5_col3, #T_6c545_row5_col4, #T_6c545_row5_col5, #T_6c545_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_6c545">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c545_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_6c545_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_6c545_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_6c545_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_6c545_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_6c545_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_6c545_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c545_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c545_row0_col0" class="data row0 col0" >0.9937</td>
#       <td id="T_6c545_row0_col1" class="data row0 col1" >0.9998</td>
#       <td id="T_6c545_row0_col2" class="data row0 col2" >0.9937</td>
#       <td id="T_6c545_row0_col3" class="data row0 col3" >0.9937</td>
#       <td id="T_6c545_row0_col4" class="data row0 col4" >0.9937</td>
#       <td id="T_6c545_row0_col5" class="data row0 col5" >0.9906</td>
#       <td id="T_6c545_row0_col6" class="data row0 col6" >0.9906</td>
#     </tr>
#     <tr>
#       <th id="T_6c545_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6c545_row1_col0" class="data row1 col0" >0.9930</td>
#       <td id="T_6c545_row1_col1" class="data row1 col1" >0.9999</td>
#       <td id="T_6c545_row1_col2" class="data row1 col2" >0.9930</td>
#       <td id="T_6c545_row1_col3" class="data row1 col3" >0.9930</td>
#       <td id="T_6c545_row1_col4" class="data row1 col4" >0.9930</td>
#       <td id="T_6c545_row1_col5" class="data row1 col5" >0.9895</td>
#       <td id="T_6c545_row1_col6" class="data row1 col6" >0.9895</td>
#     </tr>
#     <tr>
#       <th id="T_6c545_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6c545_row2_col0" class="data row2 col0" >0.9941</td>
#       <td id="T_6c545_row2_col1" class="data row2 col1" >0.9998</td>
#       <td id="T_6c545_row2_col2" class="data row2 col2" >0.9941</td>
#       <td id="T_6c545_row2_col3" class="data row2 col3" >0.9941</td>
#       <td id="T_6c545_row2_col4" class="data row2 col4" >0.9941</td>
#       <td id="T_6c545_row2_col5" class="data row2 col5" >0.9912</td>
#       <td id="T_6c545_row2_col6" class="data row2 col6" >0.9912</td>
#     </tr>
#     <tr>
#       <th id="T_6c545_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6c545_row3_col0" class="data row3 col0" >0.9941</td>
#       <td id="T_6c545_row3_col1" class="data row3 col1" >0.9998</td>
#       <td id="T_6c545_row3_col2" class="data row3 col2" >0.9941</td>
#       <td id="T_6c545_row3_col3" class="data row3 col3" >0.9941</td>
#       <td id="T_6c545_row3_col4" class="data row3 col4" >0.9941</td>
#       <td id="T_6c545_row3_col5" class="data row3 col5" >0.9912</td>
#       <td id="T_6c545_row3_col6" class="data row3 col6" >0.9912</td>
#     </tr>
#     <tr>
#       <th id="T_6c545_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6c545_row4_col0" class="data row4 col0" >0.9939</td>
#       <td id="T_6c545_row4_col1" class="data row4 col1" >0.9998</td>
#       <td id="T_6c545_row4_col2" class="data row4 col2" >0.9939</td>
#       <td id="T_6c545_row4_col3" class="data row4 col3" >0.9939</td>
#       <td id="T_6c545_row4_col4" class="data row4 col4" >0.9939</td>
#       <td id="T_6c545_row4_col5" class="data row4 col5" >0.9908</td>
#       <td id="T_6c545_row4_col6" class="data row4 col6" >0.9908</td>
#     </tr>
#     <tr>
#       <th id="T_6c545_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_6c545_row5_col0" class="data row5 col0" >0.9938</td>
#       <td id="T_6c545_row5_col1" class="data row5 col1" >0.9998</td>
#       <td id="T_6c545_row5_col2" class="data row5 col2" >0.9938</td>
#       <td id="T_6c545_row5_col3" class="data row5 col3" >0.9938</td>
#       <td id="T_6c545_row5_col4" class="data row5 col4" >0.9938</td>
#       <td id="T_6c545_row5_col5" class="data row5 col5" >0.9906</td>
#       <td id="T_6c545_row5_col6" class="data row5 col6" >0.9907</td>
#     </tr>
#     <tr>
#       <th id="T_6c545_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_6c545_row6_col0" class="data row6 col0" >0.0004</td>
#       <td id="T_6c545_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_6c545_row6_col2" class="data row6 col2" >0.0004</td>
#       <td id="T_6c545_row6_col3" class="data row6 col3" >0.0004</td>
#       <td id="T_6c545_row6_col4" class="data row6 col4" >0.0004</td>
#       <td id="T_6c545_row6_col5" class="data row6 col5" >0.0006</td>
#       <td id="T_6c545_row6_col6" class="data row6 col6" >0.0006</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_fbc76_row5_col0, #T_fbc76_row5_col1, #T_fbc76_row5_col2, #T_fbc76_row5_col3, #T_fbc76_row5_col4, #T_fbc76_row5_col5, #T_fbc76_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_fbc76">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fbc76_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_fbc76_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_fbc76_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_fbc76_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_fbc76_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_fbc76_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_fbc76_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fbc76_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fbc76_row0_col0" class="data row0 col0" >0.9943</td>
#       <td id="T_fbc76_row0_col1" class="data row0 col1" >0.9997</td>
#       <td id="T_fbc76_row0_col2" class="data row0 col2" >0.9943</td>
#       <td id="T_fbc76_row0_col3" class="data row0 col3" >0.9943</td>
#       <td id="T_fbc76_row0_col4" class="data row0 col4" >0.9943</td>
#       <td id="T_fbc76_row0_col5" class="data row0 col5" >0.9914</td>
#       <td id="T_fbc76_row0_col6" class="data row0 col6" >0.9914</td>
#     </tr>
#     <tr>
#       <th id="T_fbc76_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fbc76_row1_col0" class="data row1 col0" >0.9916</td>
#       <td id="T_fbc76_row1_col1" class="data row1 col1" >0.9998</td>
#       <td id="T_fbc76_row1_col2" class="data row1 col2" >0.9916</td>
#       <td id="T_fbc76_row1_col3" class="data row1 col3" >0.9916</td>
#       <td id="T_fbc76_row1_col4" class="data row1 col4" >0.9916</td>
#       <td id="T_fbc76_row1_col5" class="data row1 col5" >0.9873</td>
#       <td id="T_fbc76_row1_col6" class="data row1 col6" >0.9873</td>
#     </tr>
#     <tr>
#       <th id="T_fbc76_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fbc76_row2_col0" class="data row2 col0" >0.9927</td>
#       <td id="T_fbc76_row2_col1" class="data row2 col1" >0.9998</td>
#       <td id="T_fbc76_row2_col2" class="data row2 col2" >0.9927</td>
#       <td id="T_fbc76_row2_col3" class="data row2 col3" >0.9927</td>
#       <td id="T_fbc76_row2_col4" class="data row2 col4" >0.9927</td>
#       <td id="T_fbc76_row2_col5" class="data row2 col5" >0.9891</td>
#       <td id="T_fbc76_row2_col6" class="data row2 col6" >0.9891</td>
#     </tr>
#     <tr>
#       <th id="T_fbc76_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fbc76_row3_col0" class="data row3 col0" >0.9916</td>
#       <td id="T_fbc76_row3_col1" class="data row3 col1" >0.9996</td>
#       <td id="T_fbc76_row3_col2" class="data row3 col2" >0.9916</td>
#       <td id="T_fbc76_row3_col3" class="data row3 col3" >0.9916</td>
#       <td id="T_fbc76_row3_col4" class="data row3 col4" >0.9916</td>
#       <td id="T_fbc76_row3_col5" class="data row3 col5" >0.9873</td>
#       <td id="T_fbc76_row3_col6" class="data row3 col6" >0.9874</td>
#     </tr>
#     <tr>
#       <th id="T_fbc76_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fbc76_row4_col0" class="data row4 col0" >0.9936</td>
#       <td id="T_fbc76_row4_col1" class="data row4 col1" >0.9999</td>
#       <td id="T_fbc76_row4_col2" class="data row4 col2" >0.9936</td>
#       <td id="T_fbc76_row4_col3" class="data row4 col3" >0.9936</td>
#       <td id="T_fbc76_row4_col4" class="data row4 col4" >0.9936</td>
#       <td id="T_fbc76_row4_col5" class="data row4 col5" >0.9903</td>
#       <td id="T_fbc76_row4_col6" class="data row4 col6" >0.9903</td>
#     </tr>
#     <tr>
#       <th id="T_fbc76_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_fbc76_row5_col0" class="data row5 col0" >0.9927</td>
#       <td id="T_fbc76_row5_col1" class="data row5 col1" >0.9998</td>
#       <td id="T_fbc76_row5_col2" class="data row5 col2" >0.9927</td>
#       <td id="T_fbc76_row5_col3" class="data row5 col3" >0.9927</td>
#       <td id="T_fbc76_row5_col4" class="data row5 col4" >0.9927</td>
#       <td id="T_fbc76_row5_col5" class="data row5 col5" >0.9891</td>
#       <td id="T_fbc76_row5_col6" class="data row5 col6" >0.9891</td>
#     </tr>
#     <tr>
#       <th id="T_fbc76_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_fbc76_row6_col0" class="data row6 col0" >0.0011</td>
#       <td id="T_fbc76_row6_col1" class="data row6 col1" >0.0001</td>
#       <td id="T_fbc76_row6_col2" class="data row6 col2" >0.0011</td>
#       <td id="T_fbc76_row6_col3" class="data row6 col3" >0.0011</td>
#       <td id="T_fbc76_row6_col4" class="data row6 col4" >0.0011</td>
#       <td id="T_fbc76_row6_col5" class="data row6 col5" >0.0016</td>
#       <td id="T_fbc76_row6_col6" class="data row6 col6" >0.0016</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# </style>
# <table id="T_e6a4d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6a4d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e6a4d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e6a4d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e6a4d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e6a4d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e6a4d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e6a4d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e6a4d_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6a4d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e6a4d_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_e6a4d_row0_col1" class="data row0 col1" >0.9959</td>
#       <td id="T_e6a4d_row0_col2" class="data row0 col2" >0.9999</td>
#       <td id="T_e6a4d_row0_col3" class="data row0 col3" >0.9959</td>
#       <td id="T_e6a4d_row0_col4" class="data row0 col4" >0.9959</td>
#       <td id="T_e6a4d_row0_col5" class="data row0 col5" >0.9959</td>
#       <td id="T_e6a4d_row0_col6" class="data row0 col6" >0.9939</td>
#       <td id="T_e6a4d_row0_col7" class="data row0 col7" >0.9939</td>
#     </tr>
#   </tbody>
# </table>
# Transformation Pipeline and Model Successfully Saved
#
# Listo. Revisa la carpeta: c:\Users\FABIO\Downloads\IAhotelera\resultados_segmento y la subcarpeta ./Plots
